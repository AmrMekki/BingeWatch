# %% [markdown]
# THIRD STEP:

# %% [markdown]
# now we want to turn each poster into an array holding (100,100,3) with RGB values

# %% [markdown]
# currently we have an array of 1000, 3 (10000 is 100*100 from our pics)
# so we're looking for a way to turn the 10000 to a 100,100 array or extract data as 100,100,3 directly

# %%
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Dropout
from keras.models import Sequential
from keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.keras import datasets

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# %%
print(train_images.shape)
print(train_images[0].shape)
print(train_images[0][0].shape)
# Out:
# (50000, 32, 32, 3)
# (32, 32, 3)
# (32, 3)

# %%
from PIL import Image

# %%
im = Image.open('6098922.jpg')
pixels = list(im.getdata()) #get data of image
for i in range (len(pixels)): #turn tuple into list
    pixels[i] = list(pixels[i])
pixels
# listpixels =
# Out:
# [[225, 184, 156],
#  [233, 192, 164],
#  [240, 200, 174],
#  [221, 181, 155],
#  [223, 183, 158],
#  [248, 208, 183],
#  [244, 206, 183],
#  [241, 203, 180],
#  [255, 218, 199],
#  [246, 208, 189],
#  [218, 181, 165],
#  [212, 175, 159],
#  [238, 200, 187],
#  [246, 208, 195],
#  [237, 201, 189],
#  [235, 206, 192],
#  [241, 222, 207],
#  [255, 246, 229],
#  [255, 242, 226],
#  [225, 212, 196],
#  [255, 242, 229],
#  [252, 236, 223],
#  [248, 230, 220],
#  [246, 228, 216],
#  [241, 219, 208],
#  [250, 228, 214],
#  [253, 227, 212],
#  [243, 216, 197],
#  [241, 213, 191],
#  [250, 220, 194],
#  [254, 222, 197],
#  [252, 217, 187],
#  [248, 201, 171],
#  [239, 190, 157],
#  [231, 184, 154],
#  [234, 190, 161],
#  [236, 199, 170],
#  [235, 201, 174],
#  [233, 203, 179],
#  [233, 206, 185],
#  [236, 210, 193],
#  [255, 234, 218],
#  [218, 196, 183],
#  [188, 166, 153],
#  [211, 186, 179],
#  [203, 178, 171],
#  [222, 197, 192],
#  [167, 146, 143],
#  [48, 33, 38],
#  [68, 57, 65],
# ...

# %%
print(len(pixels))
print(len(pixels[0]))
# 100, 100, 3
# Out:
# 10000
# 3
