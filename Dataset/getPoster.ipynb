# %%
import pandas as pd 
import requests
from keras.models import Sequential
from tensorflow.keras import layers, models
from keras.layers.core import Dense, Dropout
from PIL import Image
import os
import PIL
import glob

# %%
data = pd.read_csv("../MovieGenreEdited.csv",encoding='latin1')
data
# Out:
#        Unnamed: 0  imdbId                           Imdb Link  \
# 0               0  114709  http://www.imdb.com/title/tt114709
# 1               1  113497  http://www.imdb.com/title/tt113497
# 2               2  113228  http://www.imdb.com/title/tt113228
# 3               3  114885  http://www.imdb.com/title/tt114885
# 4               4  113041  http://www.imdb.com/title/tt113041
# ...           ...     ...                                 ...
# 38878       38878   83291   http://www.imdb.com/title/tt83291
# 38879       38879   83168   http://www.imdb.com/title/tt83168
# 38880       38880   82875   http://www.imdb.com/title/tt82875
# 38881       38881  815258  http://www.imdb.com/title/tt815258
# 38882       38882   79142   http://www.imdb.com/title/tt79142
#
#                              Title  IMDB Score      Genre  \
# 0                        Toy Story         8.3  Animation
# 1                          Jumanji         6.9     Action
# ...

# %%
for i in range (len(data)) :

    posterUrl = data['Poster'][i]

    img = requests.get(posterUrl, allow_redirects=True)


    open(f"{data['imdbId'][i]}.jpg", 'wb').write(img.content)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/14/w335m50952gcywsdkh__krl00000gn/T/ipykernel_2881/4034826597.py in <module>
#       3     posterUrl = data['Poster'][i]
#       4
# ----> 5     img = requests.get(posterUrl, allow_redirects=True)
#       6
#       7
#
# /Applications/anaconda3/envs/neurons/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /Applications/anaconda3/envs/neurons/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
# data augmentation

image = Image.open(f"{data['imdbId'][0]}.jpg")
print(image.size)


resized_image = image.resize((100,100))
print(resized_image.size)
resized_image.save(f"{data['imdbId'][0]}.jpg")

# %%
model = models.Sequential()
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
