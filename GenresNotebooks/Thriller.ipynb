# %%
from PIL import Image
import pandas as pd
import numpy as np
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
ourGenre = 'Thriller'

# %%
data = pd.read_csv(f"../GenresCSV/{ourGenre}.csv")
data
# Out:
#       Unnamed: 0     imdbID  Genre
# 0              0  tt0080684      0
# 1              1  tt0080684      0
# 2              2  tt0080684      0
# 3              3  tt0080377      0
# 4              4  tt0080377      0
# ...          ...        ...    ...
# 2171        2171  tt4078160      1
# 2172        2172  tt1519461      1
# 2173        2173  tt2311428      1
# 2174        2174  tt2924352      1
# 2175        2175  tt4159182      1
#
# [2176 rows x 3 columns]

# %%
genre = []
poster = []

# %%
for i in range(len(data)):
    tempImage = Image.open(f"../Posters100x100/{data['imdbID'][i]}.jpg")
    poster.append(np.array(tempImage))
    genre.append(data['Genre'][i])

# %%
print(len(genre))
print(len(poster))
print(len(poster[0]))
print(len(poster[0][0]))
print(len(poster[0][0][0]))
# Out:
# 2176
# 2176
# 100
# 100
# 3

# %%
GenreStrings = [f"Not {ourGenre}", f"{ourGenre}"]

# %%
for i in range(len(poster) -1, -1 ,-1):
    if poster[i].shape != (100,100,3): 
        #some posters didnt have 100,100,3 so we deleted them
        genre.pop(i)
        poster.pop(i)
        
print(len(genre))
# Out:
# 2176

# %%
X_train, X_test, y_train, y_test = train_test_split(poster, genre, test_size=0.1)

# %%
print(len(X_train))
print(len(y_train))
print(len(X_test))
print(len(y_test))
# Out:
# 1958
# 1958
# 218
# 218

# %%
X_train = np.array(X_train) #turn them into numpy arrays
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.

print("x_train shape:", X_train.shape)
print(X_train.shape[0], "train samples")
print(X_test.shape[0], "test samples")
# Out:
# x_train shape: (1958, 100, 100, 3)
# 1958 train samples
# 218 test samples

# %%
y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)
print (y_train.shape)
print(y_test.shape)
print (y_train)
print (y_train[0])
# Out:
# (1958, 2)
# (218, 2)
# [[0. 1.]
#  [1. 0.]
#  [0. 1.]
#  ...
#  [0. 1.]
#  [1. 0.]
#  [0. 1.]]
# [0. 1.]

# %%
index = 50
plt.figure(figsize=(20, 4))
# original
plt.subplot(2, 10, 1)
# plt.figure(figsize = (15,2))
plt.imshow(X_train[index].reshape(100, 100,3))
plt.gray()
plt.axis('off')
plt.tight_layout()
plt.show()
print(y_train[index])
print(GenreStrings[np.argmax(y_train[index])])
# Out:
# [0. 1.]
# Thriller

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(100, 100, 3)))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(len(GenreStrings), activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 20000)             0
#
#  dropout (Dropout)           (None, 20000)             0
#
#  dense (Dense)               (None, 2)                 40002
#
# =================================================================
# Total params: 60,258
# Trainable params: 60,258
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='CategoricalCrossentropy', metrics=["accuracy"])

# %%
# Loads the weights
checkpoint_path = f"../Weights/{GenreStrings[1]}/cp.ckpt"
model.load_weights(checkpoint_path)
# Re-evaluate the model
loss, acc = model.evaluate(X_test, y_test, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 7/7 - 1s - loss: 0.3115 - accuracy: 0.8899 - 512ms/epoch - 73ms/step
# Restored model, accuracy: 88.99%

# %%
model.fit(X_train, y_train, epochs =5, batch_size=128, shuffle=True, validation_split=0.2)
# Out:
# Epoch 1/5
# 13/13 [==============================] - 18s 1s/step - loss: 0.1114 - accuracy: 0.9655 - val_loss: 0.2532 - val_accuracy: 0.9082
# Epoch 2/5
# 13/13 [==============================] - 17s 1s/step - loss: 0.0770 - accuracy: 0.9821 - val_loss: 0.2818 - val_accuracy: 0.9133
# Epoch 3/5
# 13/13 [==============================] - 10s 779ms/step - loss: 0.0762 - accuracy: 0.9808 - val_loss: 0.2844 - val_accuracy: 0.9082
# Epoch 4/5
# 13/13 [==============================] - 10s 752ms/step - loss: 0.0641 - accuracy: 0.9847 - val_loss: 0.3164 - val_accuracy: 0.9056
# Epoch 5/5
# 13/13 [==============================] - 10s 742ms/step - loss: 0.0656 - accuracy: 0.9834 - val_loss: 0.3164 - val_accuracy: 0.9133

# %%
model.fit(X_train, y_train, epochs =5, batch_size=128, shuffle=True, validation_split=0.2)
# Out:
# Epoch 1/5
# 13/13 [==============================] - 9s 712ms/step - loss: 0.0520 - accuracy: 0.9860 - val_loss: 0.2992 - val_accuracy: 0.9082
# Epoch 2/5
# 13/13 [==============================] - 10s 735ms/step - loss: 0.0460 - accuracy: 0.9872 - val_loss: 0.2957 - val_accuracy: 0.8980
# Epoch 3/5
# 13/13 [==============================] - 9s 706ms/step - loss: 0.0433 - accuracy: 0.9904 - val_loss: 0.3233 - val_accuracy: 0.8954
# Epoch 4/5
# 13/13 [==============================] - 10s 744ms/step - loss: 0.0378 - accuracy: 0.9917 - val_loss: 0.3202 - val_accuracy: 0.9082
# Epoch 5/5
# 13/13 [==============================] - 10s 738ms/step - loss: 0.0398 - accuracy: 0.9885 - val_loss: 0.3091 - val_accuracy: 0.9031

# %%
# Compare original images with Predicted ones
decoded_imgs1 = model.predict(X_test)
offset = 0
decoded_imgs1= decoded_imgs1[offset:]
print(decoded_imgs1.shape)
plt.figure(figsize=(20, 4))
for i in range(10):
    # original
    plt.subplot(2, 10, i + 1)
    # plt.figure(figsize = (15,2))
    plt.imshow(X_test[i+offset].reshape(100, 100,3))
    plt.gray()
    plt.axis('off')
plt.tight_layout()
plt.show()
print(decoded_imgs1[0])
print(np.argmax(decoded_imgs1[0]))
for i in range(10):
  print(f"Genre is {GenreStrings[np.argmax(y_test[i+offset])]} Predicted is {GenreStrings[np.argmax(decoded_imgs1[i])]} ({decoded_imgs1[i+offset]})")
# Out:
# (218, 2)
# [0.92121583 0.07878414]
# 0
# Genre is Thriller Predicted is Not Thriller ([0.92121583 0.07878414])
# Genre is Thriller Predicted is Thriller ([0.01816265 0.98183733])
# Genre is Not Thriller Predicted is Not Thriller ([0.9751183  0.02488177])
# Genre is Not Thriller Predicted is Not Thriller ([0.95290875 0.04709125])
# Genre is Thriller Predicted is Thriller ([0.00115865 0.99884135])
# Genre is Thriller Predicted is Not Thriller ([0.5280084 0.4719916])
# Genre is Thriller Predicted is Thriller ([3.6485184e-05 9.9996352e-01])
# Genre is Thriller Predicted is Thriller ([4.0013823e-05 9.9995995e-01])
# Genre is Not Thriller Predicted is Not Thriller ([0.9965485  0.00345152])
# Genre is Thriller Predicted is Thriller ([2.8128622e-04 9.9971873e-01])

# %%
#Evaluate the trained model
#Should have test and train genres equal
score = model.evaluate(X_test, y_test)
print("Test Loss: {:.2f}%".format(score[0]*100))
print("Test Accuracy:  {:.2f}%".format(score[1]*100))
# Out:
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2137 - accuracy: 0.9220
# Test Loss: 21.37%
# Test Accuracy:  92.20%

# %%
model.save_weights(checkpoint_path)
