# %%
from PIL import Image
import pandas as pd
import numpy as np
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
ourGenre = 'Romance'

# %%
data = pd.read_csv(f"../GenresCSV/{ourGenre}.csv")
data
# Out:
#       Unnamed: 0     imdbID  Genre
# 0              0  tt0080684      0
# 1              1  tt0080684      0
# 2              2  tt0080684      0
# 3              3  tt0080377      0
# 4              4  tt0080377      0
# ...          ...        ...    ...
# 2349        2349  tt3544326      1
# 2350        2350  tt3334212      1
# 2351        2351  tt3774466      1
# 2352        2352  tt2994832      1
# 2353        2353  tt2265431      1
#
# [2354 rows x 3 columns]

# %%
genre = []
poster = []

# %%
for i in range(len(data)):
    tempImage = Image.open(f"../Posters100x100/{data['imdbID'][i]}.jpg")
    poster.append(np.array(tempImage))
    genre.append(data['Genre'][i])

# %%
print(len(genre))
print(len(poster))
print(len(poster[0]))
print(len(poster[0][0]))
print(len(poster[0][0][0]))
# Out:
# 2354
# 2354
# 100
# 100
# 3

# %%
GenreStrings = [f"Not {ourGenre}", f"{ourGenre}"]

# %%
for i in range(len(poster) -1, -1 ,-1):
    if poster[i].shape != (100,100,3): 
        #some posters didnt have 100,100,3 so we deleted them
        genre.pop(i)
        poster.pop(i)
        
print(len(genre))
# Out:
# 2354

# %%
X_train, X_test, y_train, y_test = train_test_split(poster, genre, test_size=0.1)

# %%
print(len(X_train))
print(len(y_train))
print(len(X_test))
print(len(y_test))
# Out:
# 2118
# 2118
# 236
# 236

# %%
X_train = np.array(X_train) #turn them into numpy arrays
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.

print("x_train shape:", X_train.shape)
print(X_train.shape[0], "train samples")
print(X_test.shape[0], "test samples")
# Out:
# x_train shape: (2118, 100, 100, 3)
# 2118 train samples
# 236 test samples

# %%
y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)
print (y_train.shape)
print(y_test.shape)
print (y_train)
print (y_train[0])
# Out:
# (2118, 2)
# (236, 2)
# [[0. 1.]
#  [0. 1.]
#  [1. 0.]
#  ...
#  [0. 1.]
#  [0. 1.]
#  [1. 0.]]
# [0. 1.]

# %%
index = 50
plt.figure(figsize=(20, 4))
# original
plt.subplot(2, 10, 1)
# plt.figure(figsize = (15,2))
plt.imshow(X_train[index].reshape(100, 100,3))
plt.gray()
plt.axis('off')
plt.tight_layout()
plt.show()
print(y_train[index])
print(GenreStrings[np.argmax(y_train[index])])
# Out:
# [1. 0.]
# Not Romance

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(100, 100, 3)))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(len(GenreStrings), activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 20000)             0
#
#  dropout (Dropout)           (None, 20000)             0
#
#  dense (Dense)               (None, 2)                 40002
#
# =================================================================
# Total params: 60,258
# Trainable params: 60,258
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='CategoricalCrossentropy', metrics=["accuracy"])

# %%
# Loads the weights
checkpoint_path = f"../Weights/{GenreStrings[1]}/cp.ckpt"
model.load_weights(checkpoint_path)
# Re-evaluate the model
loss, acc = model.evaluate(X_test, y_test, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 8/8 - 0s - loss: 0.2392 - accuracy: 0.8983 - 259ms/epoch - 32ms/step
# Restored model, accuracy: 89.83%

# %%
model.fit(X_train, y_train, epochs =5, batch_size=128, shuffle=True, validation_split=0.2)
# Out:
# Epoch 1/5
# 14/14 [==============================] - 12s 843ms/step - loss: 0.1457 - accuracy: 0.9557 - val_loss: 0.1999 - val_accuracy: 0.9363
# Epoch 2/5
# 14/14 [==============================] - 13s 970ms/step - loss: 0.1061 - accuracy: 0.9764 - val_loss: 0.2172 - val_accuracy: 0.9151
# Epoch 3/5
# 14/14 [==============================] - 21s 1s/step - loss: 0.0919 - accuracy: 0.9793 - val_loss: 0.2081 - val_accuracy: 0.9340
# Epoch 4/5
# 14/14 [==============================] - 21s 2s/step - loss: 0.0798 - accuracy: 0.9823 - val_loss: 0.1871 - val_accuracy: 0.9410
# Epoch 5/5
# 14/14 [==============================] - 20s 1s/step - loss: 0.0769 - accuracy: 0.9835 - val_loss: 0.1877 - val_accuracy: 0.9340

# %%
# Compare original images with Predicted ones
decoded_imgs1 = model.predict(X_test)
offset = 0
decoded_imgs1= decoded_imgs1[offset:]
print(decoded_imgs1.shape)
plt.figure(figsize=(20, 4))
for i in range(10):
    # original
    plt.subplot(2, 10, i + 1)
    # plt.figure(figsize = (15,2))
    plt.imshow(X_test[i+offset].reshape(100, 100,3))
    plt.gray()
    plt.axis('off')
plt.tight_layout()
plt.show()
print(decoded_imgs1[0])
print(np.argmax(decoded_imgs1[0]))
for i in range(10):
  print(f"Genre is {GenreStrings[np.argmax(y_test[i+offset])]} Predicted is {GenreStrings[np.argmax(decoded_imgs1[i])]} ({decoded_imgs1[i+offset]})")
# Out:
# (236, 2)
# [0.44313282 0.5568672 ]
# 1
# Genre is Not Romance Predicted is Romance ([0.44313282 0.5568672 ])
# Genre is Not Romance Predicted is Not Romance ([0.96706855 0.03293145])
# Genre is Not Romance Predicted is Not Romance ([0.9645497  0.03545032])
# Genre is Romance Predicted is Not Romance ([0.82384723 0.17615277])
# Genre is Romance Predicted is Romance ([7.057102e-04 9.992943e-01])
# Genre is Romance Predicted is Romance ([0.02933795 0.97066206])
# Genre is Not Romance Predicted is Not Romance ([0.96799904 0.03200096])
# Genre is Romance Predicted is Romance ([0.07323777 0.9267623 ])
# Genre is Not Romance Predicted is Not Romance ([0.93486124 0.06513882])
# Genre is Not Romance Predicted is Not Romance ([0.9932114  0.00678863])

# %%
#Evaluate the trained model
#Should have test and train genres equal
score = model.evaluate(X_test, y_test)
print("Test Loss: {:.2f}%".format(score[0]*100))
print("Test Accuracy:  {:.2f}%".format(score[1]*100))
# Out:
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1886 - accuracy: 0.9195
# Test Loss: 18.86%
# Test Accuracy:  91.95%

# %%
model.save_weights(checkpoint_path)
