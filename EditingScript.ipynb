# %%
import pandas as pd

# %%
data = pd.read_csv("MovieGenre.csv",encoding='latin1')
data
# Out:
#        imdbId                           Imdb Link  \
# 0      114709  http://www.imdb.com/title/tt114709
# 1      113497  http://www.imdb.com/title/tt113497
# 2      113228  http://www.imdb.com/title/tt113228
# 3      114885  http://www.imdb.com/title/tt114885
# 4      113041  http://www.imdb.com/title/tt113041
# ...       ...                                 ...
# 40103   83168   http://www.imdb.com/title/tt83168
# 40104   82875   http://www.imdb.com/title/tt82875
# 40105  815258  http://www.imdb.com/title/tt815258
# 40106   79142   http://www.imdb.com/title/tt79142
# 40107   70710   http://www.imdb.com/title/tt70710
#
#                                     Title  IMDB Score  \
# 0                        Toy Story (1995)         8.3
# 1                          Jumanji (1995)         6.9
# 2                 Grumpier Old Men (1995)         6.6
# 3                Waiting to Exhale (1995)         5.7
# 4      Father of the Bride Part II (1995)         5.9
# ...                                   ...         ...
# 40103               Tanya's Island (1980)         4.3
# 40104               Pacific Banana (1981)         4.7
# 40105  Werewolf in a Womens Prison (2006)         4.5
# 40106              Xiao zi ming da (1979)         6.5
# 40107                     Snatched (1973)         6.5
#
#                             Genre  \
# 0      Animation|Adventure|Comedy
# 1         Action|Adventure|Family
# 2                  Comedy|Romance
# 3            Comedy|Drama|Romance
# 4           Comedy|Family|Romance
# ...                           ...
# 40103                       Drama
# 40104                      Comedy
# 40105                      Horror
# 40106               Action|Comedy
# 40107        Crime|Drama|Thriller
#
#                                                   Poster
# 0      https://images-na.ssl-images-amazon.com/images...
# 1      https://images-na.ssl-images-amazon.com/images...
# 2      https://images-na.ssl-images-amazon.com/images...
# 3      https://images-na.ssl-images-amazon.com/images...
# 4      https://images-na.ssl-images-amazon.com/images...
# ...                                                  ...
# 40103  https://images-na.ssl-images-amazon.com/images...
# 40104  https://images-na.ssl-images-amazon.com/images...
# 40105  https://images-na.ssl-images-amazon.com/images...
# 40106  https://images-na.ssl-images-amazon.com/images...
# 40107                                                NaN
#
# [40108 rows x 6 columns]

# %%
data.dropna(subset = ["Poster"], inplace=True) # to drop rows that have NaN in Poster
data = data.reset_index(drop=True) #reassign index because of deleted rows
data
# Out:
#        imdbId                           Imdb Link  \
# 0      114709  http://www.imdb.com/title/tt114709
# 1      113497  http://www.imdb.com/title/tt113497
# 2      113228  http://www.imdb.com/title/tt113228
# 3      114885  http://www.imdb.com/title/tt114885
# 4      113041  http://www.imdb.com/title/tt113041
# ...       ...                                 ...
# 39378   83291   http://www.imdb.com/title/tt83291
# 39379   83168   http://www.imdb.com/title/tt83168
# 39380   82875   http://www.imdb.com/title/tt82875
# 39381  815258  http://www.imdb.com/title/tt815258
# 39382   79142   http://www.imdb.com/title/tt79142
#
#                                     Title  IMDB Score  \
# 0                        Toy Story (1995)         8.3
# 1                          Jumanji (1995)         6.9
# 2                 Grumpier Old Men (1995)         6.6
# 3                Waiting to Exhale (1995)         5.7
# 4      Father of the Bride Part II (1995)         5.9
# ...                                   ...         ...
# 39378               Los violadores (1981)         5.5
# 39379               Tanya's Island (1980)         4.3
# 39380               Pacific Banana (1981)         4.7
# 39381  Werewolf in a Womens Prison (2006)         4.5
# 39382              Xiao zi ming da (1979)         6.5
#
#                             Genre  \
# 0      Animation|Adventure|Comedy
# 1         Action|Adventure|Family
# 2                  Comedy|Romance
# 3            Comedy|Drama|Romance
# 4           Comedy|Family|Romance
# ...                           ...
# 39378             Action|Thriller
# 39379                       Drama
# 39380                      Comedy
# 39381                      Horror
# 39382               Action|Comedy
#
#                                                   Poster
# 0      https://images-na.ssl-images-amazon.com/images...
# 1      https://images-na.ssl-images-amazon.com/images...
# 2      https://images-na.ssl-images-amazon.com/images...
# 3      https://images-na.ssl-images-amazon.com/images...
# 4      https://images-na.ssl-images-amazon.com/images...
# ...                                                  ...
# 39378  https://images-na.ssl-images-amazon.com/images...
# 39379  https://images-na.ssl-images-amazon.com/images...
# 39380  https://images-na.ssl-images-amazon.com/images...
# 39381  https://images-na.ssl-images-amazon.com/images...
# 39382  https://images-na.ssl-images-amazon.com/images...
#
# [39383 rows x 6 columns]

# %%
data['Title']
# Out:
# 0                          Toy Story (1995)
# 1                            Jumanji (1995)
# 2                   Grumpier Old Men (1995)
# 3                  Waiting to Exhale (1995)
# 4        Father of the Bride Part II (1995)
#                         ...
# 39378                 Los violadores (1981)
# 39379                 Tanya's Island (1980)
# 39380                 Pacific Banana (1981)
# 39381    Werewolf in a Womens Prison (2006)
# 39382                Xiao zi ming da (1979)
# Name: Title, Length: 39383, dtype: object

# %%
year = []
title = []

# %%
for i in range(len(data)):
    temp = data['Title'][i] #take the title with year
    temp = temp.split("(") #split into 0:title  1: year)
    title.append(temp[0][:-1]) #add title to title array without final space
    try:
        temp[1] = temp[1][:-1] #remove ) from year
    except:
        year.append('2022') #if no year we insert 2022 temporarily
        continue
    year.append(temp[1])

# %%
titleDF = pd.DataFrame(title)
titleDF
# Out:
#                                  0
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 39378               Los violadores
# 39379               Tanya's Island
# 39380               Pacific Banana
# 39381  Werewolf in a Womens Prison
# 39382              Xiao zi ming da
#
# [39383 rows x 1 columns]

# %%
yearDF = pd.DataFrame(year)
yearDF
# Out:
#           0
# 0      1995
# 1      1995
# 2      1995
# 3      1995
# 4      1995
# ...     ...
# 39378  1981
# 39379  1980
# 39380  1981
# 39381  2006
# 39382  1979
#
# [39383 rows x 1 columns]

# %%
data['Title'] = titleDF
data['Year'] = yearDF

# %%
data = data[data['Year'] !='2022'] #now we don't have movies that had no year
data
# Out:
#        imdbId                           Imdb Link  \
# 0      114709  http://www.imdb.com/title/tt114709
# 1      113497  http://www.imdb.com/title/tt113497
# 2      113228  http://www.imdb.com/title/tt113228
# 3      114885  http://www.imdb.com/title/tt114885
# 4      113041  http://www.imdb.com/title/tt113041
# ...       ...                                 ...
# 39378   83291   http://www.imdb.com/title/tt83291
# 39379   83168   http://www.imdb.com/title/tt83168
# 39380   82875   http://www.imdb.com/title/tt82875
# 39381  815258  http://www.imdb.com/title/tt815258
# 39382   79142   http://www.imdb.com/title/tt79142
#
#                              Title  IMDB Score                       Genre  \
# 0                        Toy Story         8.3  Animation|Adventure|Comedy
# 1                          Jumanji         6.9     Action|Adventure|Family
# 2                 Grumpier Old Men         6.6              Comedy|Romance
# 3                Waiting to Exhale         5.7        Comedy|Drama|Romance
# 4      Father of the Bride Part II         5.9       Comedy|Family|Romance
# ...                            ...         ...                         ...
# 39378               Los violadores         5.5             Action|Thriller
# 39379               Tanya's Island         4.3                       Drama
# 39380               Pacific Banana         4.7                      Comedy
# 39381  Werewolf in a Womens Prison         4.5                      Horror
# 39382              Xiao zi ming da         6.5               Action|Comedy
#
#                                                   Poster  Year
# 0      https://images-na.ssl-images-amazon.com/images...  1995
# 1      https://images-na.ssl-images-amazon.com/images...  1995
# 2      https://images-na.ssl-images-amazon.com/images...  1995
# 3      https://images-na.ssl-images-amazon.com/images...  1995
# 4      https://images-na.ssl-images-amazon.com/images...  1995
# ...                                                  ...   ...
# 39378  https://images-na.ssl-images-amazon.com/images...  1981
# 39379  https://images-na.ssl-images-amazon.com/images...  1980
# 39380  https://images-na.ssl-images-amazon.com/images...  1981
# 39381  https://images-na.ssl-images-amazon.com/images...  2006
# 39382  https://images-na.ssl-images-amazon.com/images...  1979
#
# [38883 rows x 7 columns]

# %%
data = data.reset_index(drop=True) #reassign index because of deleted rows
data
# Out:
#        imdbId                           Imdb Link  \
# 0      114709  http://www.imdb.com/title/tt114709
# 1      113497  http://www.imdb.com/title/tt113497
# 2      113228  http://www.imdb.com/title/tt113228
# 3      114885  http://www.imdb.com/title/tt114885
# 4      113041  http://www.imdb.com/title/tt113041
# ...       ...                                 ...
# 38878   83291   http://www.imdb.com/title/tt83291
# 38879   83168   http://www.imdb.com/title/tt83168
# 38880   82875   http://www.imdb.com/title/tt82875
# 38881  815258  http://www.imdb.com/title/tt815258
# 38882   79142   http://www.imdb.com/title/tt79142
#
#                              Title  IMDB Score                       Genre  \
# 0                        Toy Story         8.3  Animation|Adventure|Comedy
# 1                          Jumanji         6.9     Action|Adventure|Family
# 2                 Grumpier Old Men         6.6              Comedy|Romance
# 3                Waiting to Exhale         5.7        Comedy|Drama|Romance
# 4      Father of the Bride Part II         5.9       Comedy|Family|Romance
# ...                            ...         ...                         ...
# 38878               Los violadores         5.5             Action|Thriller
# 38879               Tanya's Island         4.3                       Drama
# 38880               Pacific Banana         4.7                      Comedy
# 38881  Werewolf in a Womens Prison         4.5                      Horror
# 38882              Xiao zi ming da         6.5               Action|Comedy
#
#                                                   Poster  Year
# 0      https://images-na.ssl-images-amazon.com/images...  1995
# 1      https://images-na.ssl-images-amazon.com/images...  1995
# 2      https://images-na.ssl-images-amazon.com/images...  1995
# 3      https://images-na.ssl-images-amazon.com/images...  1995
# 4      https://images-na.ssl-images-amazon.com/images...  1995
# ...                                                  ...   ...
# 38878  https://images-na.ssl-images-amazon.com/images...  1981
# 38879  https://images-na.ssl-images-amazon.com/images...  1980
# 38880  https://images-na.ssl-images-amazon.com/images...  1981
# 38881  https://images-na.ssl-images-amazon.com/images...  2006
# 38882  https://images-na.ssl-images-amazon.com/images...  1979
#
# [38883 rows x 7 columns]

# %%
data['Genre'] = data['Genre'].str.split('|')
data
# Out:
#        imdbId                           Imdb Link  \
# 0      114709  http://www.imdb.com/title/tt114709
# 1      113497  http://www.imdb.com/title/tt113497
# 2      113228  http://www.imdb.com/title/tt113228
# 3      114885  http://www.imdb.com/title/tt114885
# 4      113041  http://www.imdb.com/title/tt113041
# ...       ...                                 ...
# 38878   83291   http://www.imdb.com/title/tt83291
# 38879   83168   http://www.imdb.com/title/tt83168
# 38880   82875   http://www.imdb.com/title/tt82875
# 38881  815258  http://www.imdb.com/title/tt815258
# 38882   79142   http://www.imdb.com/title/tt79142
#
#                              Title  IMDB Score  \
# 0                        Toy Story         8.3
# 1                          Jumanji         6.9
# 2                 Grumpier Old Men         6.6
# 3                Waiting to Exhale         5.7
# 4      Father of the Bride Part II         5.9
# ...                            ...         ...
# 38878               Los violadores         5.5
# 38879               Tanya's Island         4.3
# 38880               Pacific Banana         4.7
# 38881  Werewolf in a Womens Prison         4.5
# 38882              Xiao zi ming da         6.5
#
#                                 Genre  \
# 0      [Animation, Adventure, Comedy]
# 1         [Action, Adventure, Family]
# 2                   [Comedy, Romance]
# 3            [Comedy, Drama, Romance]
# 4           [Comedy, Family, Romance]
# ...                               ...
# 38878              [Action, Thriller]
# 38879                         [Drama]
# 38880                        [Comedy]
# 38881                        [Horror]
# 38882                [Action, Comedy]
#
#                                                   Poster  Year
# 0      https://images-na.ssl-images-amazon.com/images...  1995
# 1      https://images-na.ssl-images-amazon.com/images...  1995
# 2      https://images-na.ssl-images-amazon.com/images...  1995
# 3      https://images-na.ssl-images-amazon.com/images...  1995
# 4      https://images-na.ssl-images-amazon.com/images...  1995
# ...                                                  ...   ...
# 38878  https://images-na.ssl-images-amazon.com/images...  1981
# 38879  https://images-na.ssl-images-amazon.com/images...  1980
# 38880  https://images-na.ssl-images-amazon.com/images...  1981
# 38881  https://images-na.ssl-images-amazon.com/images...  2006
# 38882  https://images-na.ssl-images-amazon.com/images...  1979
#
# [38883 rows x 7 columns]

# %%
genre = []

# %%
for i in range(len(data)):
    genre.append(data['Genre'][i])
genre
# Out:
# [['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Family'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Family', 'Romance'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Fantasy', 'Horror'],
#  ['Animation', 'Adventure', 'Drama'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Crime', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Comedy'],
#  ['Adventure', 'Comedy', 'Crime'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Comedy', 'Crime', 'Thriller'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Drama', 'Fantasy', 'Mystery'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Fantasy', 'Sci-Fi'],
#  ['Crime', 'Drama', 'Romance'],
#  ['Biography', 'Drama'],
#  ['Mystery', 'Sci-Fi', 'Thriller'],
#  ['Adventure', 'Romance'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Biography', 'Drama', 'Romance'],
#  ['Crime', 'Drama'],
#  ['Adventure', 'Drama', 'Family'],
#  ['Comedy', 'Family', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'Thriller'],
#  ['Drama', 'War'],
#  ['Action', 'Crime', 'Drama'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Animation', 'Adventure', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Comedy', 'Fantasy', 'Romance'],
#  ['Drama'],
#  ['Comedy', 'Family', 'Sport'],
#  ['Drama', 'Music'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Biography', 'Comedy', 'Drama'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Drama', 'Family', 'Fantasy'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama', 'Music'],
#  ['Comedy', 'Crime'],
#  ['Comedy', 'Crime', 'Romance'],
#  ['Comedy'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Drama'],
#  ['Comedy'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Crime', 'Horror'],
#  ['Action', 'Crime', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'History'],
#  ['Romance', 'Drama'],
#  ['Comedy', 'Thriller'],
#  ['Sci-Fi', 'Thriller'],
#  ['Documentary', 'Biography', 'Music'],
#  ['Drama', 'Thriller'],
#  ['Drama', 'Thriller'],
#  ['Drama', 'Family'],
#  ['Crime', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Adventure', 'Drama'],
#  ['Comedy', 'Adventure', 'Family'],
#  ['Comedy'],
#  ['Action', 'Crime', 'Drama'],
#  ['Drama'],
#  ['Drama', 'Horror', 'Romance'],
#  ['Comedy', 'Fantasy', 'Horror'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Comedy'],
#  ['Crime', 'Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Documentary', 'Biography'],
#  ['Drama'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Comedy'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Comedy', 'Family', 'Sport'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Documentary'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Biography', 'Drama', 'History'],
#  ['Crime', 'Drama'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Drama'],
#  ['Comedy'],
#  ['Documentary', 'Biography', 'War'],
#  ['Crime', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Comedy'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Comedy'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Drama'],
#  ['Documentary', 'Biography', 'Mystery'],
#  ['Comedy', 'Romance'],
#  ['Drama'],
#  ['Drama', 'Romance', 'War'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Documentary'],
#  ['Comedy'],
#  ['Documentary', 'Biography'],
#  ['Comedy', 'Romance'],
#  ['Drama'],
#  ['Drama', 'Romance'],
#  ['Comedy'],
#  ['Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Family', 'Adventure', 'Drama'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Adventure', 'Drama', 'History'],
#  ['Adventure', 'Biography', 'History'],
#  ['Horror'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Drama'],
#  ['Action', 'Drama'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Comedy', 'Family', 'Fantasy'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Action', 'Adventure', 'Mystery'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Documentary', 'Biography', 'Comedy'],
#  ['Action', 'Thriller'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Action', 'Adventure', 'Romance'],
#  ['Adventure', 'Drama', 'Family'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Crime', 'Sci-Fi'],
#  ['Action', 'Crime', 'Sci-Fi'],
#  ['Comedy'],
#  ['Drama'],
#  ['Comedy', 'Drama'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Drama', 'Comedy'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Adventure', 'Family'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Horror', 'Thriller'],
#  ['Drama', 'Horror'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Comedy'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy', 'Drama', 'Fantasy'],
#  ['Drama'],
#  ['Drama', 'Romance'],
#  ['Documentary', 'Music'],
#  ['Drama'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Horror', 'Sci-Fi'],
#  ['Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Drama', 'Musical', 'Romance'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama', 'Fantasy'],
#  ['Biography', 'Drama', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Documentary'],
#  ['Drama', 'Romance'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Biography', 'Western'],
#  ['Drama'],
#  ['Adventure', 'Comedy', 'Crime'],
#  ['Drama', 'War'],
#  ['Drama', 'War'],
#  ['Drama', 'Romance'],
#  ['Comedy'],
#  ['Drama', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Drama'],
#  ['Drama', 'Horror', 'Mystery'],
#  ['Drama', 'Romance'],
#  ['Comedy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Thriller'],
#  ['Thriller'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Crime', 'Comedy', 'Fantasy'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Comedy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama'],
#  ['Comedy', 'Crime', 'Romance'],
#  ['Biography', 'Comedy', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Adventure', 'Family'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Fantasy', 'Horror', 'Thriller'],
#  ['Drama', 'Family', 'Fantasy'],
#  ['Biography', 'Drama', 'Music'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Animation', 'Action', 'Adventure'],
#  ['Crime', 'Drama'],
#  ['Documentary', 'Drama', 'Sport'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Comedy'],
#  ['Biography', 'Drama', 'Music'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'Fantasy', 'Horror'],
#  ['Biography', 'Drama', 'History'],
#  ['Comedy', 'Crime'],
#  ['Comedy', 'Romance', 'Sci-Fi'],
#  ['Action', 'Crime', 'Drama'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Drama', 'Family', 'Romance'],
#  ['Drama', 'Family', 'Fantasy'],
#  ['Drama'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Romance', 'War'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Crime', 'Drama'],
#  ['Crime', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama'],
#  ['Biography', 'Comedy', 'Drama'],
#  ['Drama', 'Horror', 'Romance'],
#  ['Comedy', 'Family'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Family', 'Fantasy'],
#  ['Comedy'],
#  ['Drama'],
#  ['Drama', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Drama'],
#  ['Crime', 'Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy', 'Horror'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Crime', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Crime', 'Drama'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Romance', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Crime', 'Drama'],
#  ['Drama'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Biography', 'Drama', 'History'],
#  ['Drama', 'Romance'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Action', 'Romance', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Mystery', 'Romance'],
#  ['Drama', 'Music', 'Mystery'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Family', 'Comedy'],
#  ['Drama', 'Horror', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Drama', 'Family', 'Fantasy'],
#  ['Action', 'Crime', 'Drama'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Crime', 'Drama'],
#  ['Crime', 'Thriller'],
#  ['Drama', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Crime'],
#  ['Comedy', 'Drama'],
#  ['Adventure', 'Comedy'],
#  ['Drama', 'History', 'War'],
#  ['Action', 'Comedy', 'Sci-Fi'],
#  ['Action', 'Fantasy', 'Horror'],
#  ['Action', 'Adventure', 'Mystery'],
#  ['Crime', 'Horror', 'Thriller'],
#  ['Biography', 'Drama', 'Romance'],
#  ['Horror', 'Sci-Fi', 'Thriller'],
#  ['Adventure', 'Comedy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Crime', 'Thriller'],
#  ['Drama', 'War'],
#  ['Drama'],
#  ['Action', 'Crime', 'Sci-Fi'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Comedy'],
#  ['Comedy', 'Music'],
#  ['Biography', 'Drama', 'Music'],
#  ['Drama', 'Romance', 'Thriller'],
#  ['Comedy', 'Crime'],
#  ['Action', 'Crime', 'Drama'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Drama', 'Fantasy'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Comedy', 'Family', 'Fantasy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Crime', 'Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Comedy', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Adventure', 'Family', 'Romance'],
#  ['Documentary', 'Biography', 'History'],
#  ['Animation', 'Adventure', 'Drama'],
#  ['Drama'],
#  ['Fantasy', 'Horror', 'Mystery'],
#  ['Comedy', 'Family', 'Fantasy'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Biography', 'Drama'],
#  ['Comedy', 'Crime'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Family'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Crime'],
#  ['Action', 'Adventure', 'Crime'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Crime', 'Sci-Fi'],
#  ['Action', 'Comedy', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Horror', 'Romance'],
#  ['Adventure', 'Biography', 'Crime'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Drama'],
#  ['Drama', 'History', 'Romance'],
#  ['Action', 'Comedy'],
#  ['Crime', 'Drama', 'Romance'],
#  ['Animation', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Action', 'Comedy', 'Thriller'],
#  ['Drama', 'Mystery', 'Romance'],
#  ['Drama', 'Comedy', 'Crime'],
#  ['Horror'],
#  ['Documentary'],
#  ['Adventure', 'Crime', 'Drama'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Thriller'],
#  ['Comedy'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Documentary'],
#  ['Action', 'Fantasy', 'Romance'],
#  ['Crime', 'Drama'],
#  ['Fantasy', 'Horror', 'Mystery'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Crime', 'Drama', 'Sport'],
#  ['Comedy', 'Fantasy'],
#  ['Documentary', 'Comedy'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Crime', 'Music'],
#  ['Comedy', 'Family', 'Sport'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Romance', 'Western'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Family'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Adventure', 'Drama', 'Family'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Action', 'Crime', 'Drama'],
#  ['Drama', 'Sport'],
#  ['Drama', 'Romance'],
#  ['Horror', 'Sci-Fi'],
#  ['Drama', 'Mystery', 'Romance'],
#  ['Crime', 'Drama'],
#  ['Adventure', 'Comedy', 'Romance'],
#  ['Drama', 'Comedy'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Western'],
#  ['Comedy', 'Mystery'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Comedy', 'Sci-Fi'],
#  ['Mystery', 'Romance', 'Thriller'],
#  ['Comedy', 'Crime', 'Thriller'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Drama'],
#  ['Comedy', 'Romance'],
#  ['Comedy'],
#  ['Action', 'Crime', 'Sci-Fi'],
#  ['Documentary', 'Adventure', 'Sport'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Crime', 'Thriller'],
#  ['Drama', 'Music', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'Thriller'],
#  ['Comedy', 'Music'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Mystery', 'Romance'],
#  ['Comedy', 'Crime', 'Mystery'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Adventure', 'Drama', 'Family'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Action', 'Crime', 'Drama'],
#  ['Drama', 'History', 'Western'],
#  ['Action', 'Adventure', 'Crime'],
#  ['Comedy', 'Crime', 'Family'],
#  ['Drama', 'Romance'],
#  ['Comedy'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Action', 'Thriller'],
#  ['Action', 'Biography', 'Drama'],
#  ['Action', 'Comedy'],
#  ['Comedy'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Music', 'Romance'],
#  ['Comedy', 'Drama', 'Fantasy'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'War'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Biography', 'Drama'],
#  ['Romance', 'Comedy', 'Drama'],
#  ['Biography', 'Drama', 'Music'],
#  ['Crime', 'Comedy', 'Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Adventure', 'Sci-Fi', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Crime', 'Thriller'],
#  ['Drama', 'History'],
#  ['Family', 'Adventure'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Comedy', 'Family'],
#  ['Comedy', 'Western'],
#  ['Drama', 'Romance'],
#  ['Comedy'],
#  ['Crime', 'Mystery', 'Thriller'],
#  ['Drama'],
#  ['Comedy', 'Mystery'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Biography', 'Drama', 'Horror'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Drama', 'Family'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Drama', 'Sci-Fi'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Biography', 'Drama', 'Fantasy'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Drama', 'Music', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Action', 'Drama', 'Sport'],
#  ['Horror', 'Sci-Fi', 'Thriller'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Crime', 'Sci-Fi'],
#  ['Adventure', 'Comedy', 'Musical'],
#  ['Action', 'Crime', 'Drama'],
#  ['Crime', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Drama'],
#  ['Biography', 'Drama'],
#  ['Biography', 'Drama', 'History'],
#  ['Comedy', 'Drama', 'Sport'],
#  ['Biography', 'Drama'],
#  ['Drama'],
#  ['Drama', 'Family', 'Fantasy'],
#  ['Comedy', 'Crime', 'Horror'],
#  ['Action', 'Adventure', 'Crime'],
#  ['Biography', 'Drama', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Comedy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Mystery'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Thriller'],
#  ['Sci-Fi', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Crime', 'Mystery'],
#  ['Drama'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Action', 'Adventure', 'Crime'],
#  ['Action', 'Comedy', 'Mystery'],
#  ['Biography', 'Drama', 'Music'],
#  ['Comedy', 'Romance', 'Drama'],
#  ['Animation', 'Family', 'Fantasy'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Action', 'Biography', 'Drama'],
#  ['Thriller', 'Crime', 'Drama'],
#  ['Crime', 'Drama', 'Romance'],
#  ['Documentary', 'History'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Comedy', 'Drama'],
#  ['Drama'],
#  ['Drama', 'Romance', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Comedy'],
#  ['Horror'],
#  ['Comedy', 'Romance'],
#  ['Comedy'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Family', 'Sport'],
#  ['Drama'],
#  ['Drama'],
#  ['Comedy'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Family', 'Romance'],
#  ['Comedy'],
#  ['Adventure', 'Drama', 'Family'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama', 'History'],
#  ['Documentary', 'History'],
#  ['Comedy', 'Romance'],
#  ['Biography', 'Comedy', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Comedy'],
#  ['Comedy', 'Family'],
#  ['Drama', 'Fantasy', 'Romance'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Adventure', 'Drama', 'Western'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Action', 'Adventure'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Animation', 'Family', 'Fantasy'],
#  ['Animation', 'Family', 'Fantasy'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Drama', 'Fantasy'],
#  ['Action', 'Adventure', 'Western'],
#  ['Crime', 'Romance', 'Thriller'],
#  ['Drama'],
#  ['Documentary', 'Music'],
#  ['Comedy'],
#  ['Documentary'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Horror'],
#  ['Drama', 'Romance'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Animation', 'Adventure', 'Fantasy'],
#  ['Horror', 'Sci-Fi'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Thriller', 'Mystery'],
#  ['Comedy', 'Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Drama'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Family', 'Sport'],
#  ['Drama'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Drama', 'Comedy'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Crime', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Animation', 'Adventure', 'Family'],
#  ['Drama', 'War'],
#  ['Comedy'],
#  ['Action', 'Comedy', 'Family'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Thriller'],
#  ['Comedy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Horror', 'Thriller'],
#  ['Adventure', 'Comedy', 'Romance'],
#  ['Drama'],
#  ['Comedy'],
#  ['Drama'],
#  ['Action', 'Drama', 'Mystery'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Comedy', 'Drama', 'Mystery'],
#  ['Drama', 'Romance'],
#  ['Comedy'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Biography', 'Drama'],
#  ['Drama', 'War'],
#  ['Comedy', 'Sport'],
#  ['Comedy', 'Drama'],
#  ['Musical'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Animation', 'Adventure', 'Family'],
#  ['Drama', 'Thriller'],
#  ['Comedy'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Comedy', 'Drama', 'War'],
#  ['Drama', 'Romance', 'War'],
#  ['Action', 'Sport'],
#  ['Drama'],
#  ['Drama'],
#  ['Comedy', 'Horror', 'Sci-Fi'],
#  ['Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Adventure', 'Comedy', 'Fantasy'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Comedy', 'Horror', 'Sci-Fi'],
#  ['Short', 'Drama', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Documentary', 'Drama'],
#  ['Documentary', 'War'],
#  ['Drama', 'Thriller'],
#  ['Drama'],
#  ['Drama', 'Romance'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Romance', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Drama'],
#  ['Comedy'],
#  ['Comedy', 'Drama'],
#  ['Biography', 'Drama', 'History'],
#  ['Drama'],
#  ['Mystery', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Drama', 'Sport'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Comedy', 'Romance'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Comedy', 'Sport'],
#  ['Family', 'Adventure'],
#  ['Crime', 'Drama', 'Romance'],
#  ['Drama'],
#  ['Drama', 'Fantasy', 'Western'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Fantasy'],
#  ['Comedy', 'Romance', 'Sci-Fi'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Drama'],
#  ['Documentary', 'Biography'],
#  ['Drama'],
#  ['Drama', 'Fantasy', 'Horror'],
#  ['Comedy', 'Sport'],
#  ['Drama', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Animation', 'Drama'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Crime', 'Drama'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Comedy'],
#  ['Comedy', 'Fantasy', 'Horror'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Action', 'Sci-Fi'],
#  ['Drama'],
#  ['Animation', 'Action', 'Crime'],
#  ['Fantasy', 'Horror'],
#  ['Comedy', 'Action'],
#  ['Comedy', 'Drama'],
#  ['Animation', 'Short', 'Comedy'],
#  ['Crime', 'Drama', 'Film-Noir'],
#  ['Comedy', 'Adventure'],
#  ['Sci-Fi', 'Thriller'],
#  ['Drama', 'War'],
#  ['Comedy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Adventure', 'Drama', 'Family'],
#  ['Adventure', 'Drama', 'Family'],
#  ['Documentary', 'Biography', 'Music'],
#  ['Action', 'Drama'],
#  ['Drama'],
#  ['Documentary', 'Biography'],
#  ['Drama', 'War'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Fantasy'],
#  ['Biography', 'Drama'],
#  ['Drama', 'Comedy'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Drama', 'Musical'],
#  ['Comedy'],
#  ['Drama'],
#  ['Drama'],
#  ['Horror', 'Mystery'],
#  ['Comedy', 'Drama'],
#  ['Western'],
#  ['Drama'],
#  ['Romance', 'Comedy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Drama', 'Mystery', 'Romance'],
#  ['Action', 'Drama', 'Sport'],
#  ['Animation', 'Drama', 'Family'],
#  ['Comedy', 'Drama', 'Thriller'],
#  ['Comedy', 'Sport'],
#  ['Action', 'Drama', 'Mystery'],
#  ['Comedy', 'Romance', 'Sci-Fi'],
#  ['Drama'],
#  ['Drama', 'Romance', 'War'],
#  ['Documentary', 'Music'],
#  ['Fantasy'],
#  ['Biography', 'Drama'],
#  ['Crime', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Comedy', 'Fantasy', 'Horror'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Drama', 'Fantasy', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Comedy', 'Romance'],
#  ['Adventure', 'Family'],
#  ['Action', 'Adventure', 'Crime'],
#  ['Comedy', 'Family', 'Fantasy'],
#  ['Drama', 'Fantasy'],
#  ['Comedy', 'Family'],
#  ['Crime', 'Drama', 'Romance'],
#  ['Action', 'Mystery', 'Thriller'],
#  ['Drama', 'War'],
#  ['Comedy'],
#  ['Comedy', 'Drama'],
#  ['Adventure', 'Drama'],
#  ['Drama', 'Romance', 'Thriller'],
#  ['Drama', 'Romance', 'War'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'History', 'Mystery'],
#  ['Comedy', 'Crime', 'Romance'],
#  nan,
#  ['Drama', 'Mystery'],
#  ['Adventure', 'Drama', 'Family'],
#  ['Comedy', 'Fantasy', 'Musical'],
#  ['Comedy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Crime', 'Thriller'],
#  ['Comedy', 'Crime', 'Romance'],
#  ['Comedy'],
#  ['Drama'],
#  ['Action', 'Drama', 'Sci-Fi'],
#  ['Comedy', 'Family', 'Fantasy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Fantasy', 'Thriller'],
#  ['Comedy', 'Family'],
#  ['Drama', 'Horror'],
#  ['Comedy', 'Fantasy', 'Horror'],
#  ['Drama'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Drama', 'Romance'],
#  ['Drama'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Crime', 'Drama'],
#  ['Biography', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Music'],
#  ['Drama'],
#  ['Drama'],
#  ['Comedy', 'Romance'],
#  ['Drama'],
#  ['Crime', 'Drama'],
#  ['Comedy'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Drama'],
#  ['Crime', 'Romance', 'Thriller'],
#  ['Comedy'],
#  ['Comedy', 'Crime', 'Thriller'],
#  ['Crime', 'Drama', 'Music'],
#  ['Comedy', 'Crime'],
#  ['Comedy', 'Romance'],
#  ['Drama'],
#  ['Drama'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Comedy', 'Drama'],
#  ['Drama'],
#  ['Horror', 'Mystery', 'Sci-Fi'],
#  ['Horror', 'Sci-Fi', 'Thriller'],
#  ['Family', 'Comedy'],
#  ['Drama', 'Thriller'],
#  ['Drama'],
#  ['Comedy', 'Family', 'Fantasy'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Drama', 'Romance', 'War'],
#  ['Animation', 'Adventure', 'Family'],
#  ['Romance', 'Drama'],
#  ['Crime', 'Mystery', 'Romance'],
#  ['Horror', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Romance', 'War'],
#  ['Drama', 'Romance'],
#  ['Drama'],
#  ['Drama'],
#  ['Adventure', 'Drama', 'History'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Musical', 'Romance'],
#  ['Drama', 'Musical', 'Romance'],
#  ['Comedy', 'Musical', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Mystery', 'Romance', 'Thriller'],
#  ['Mystery', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Crime', 'Drama', 'Film-Noir'],
#  ['Comedy', 'Musical', 'Romance'],
#  ['Action', 'Adventure', 'Mystery'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Mystery', 'Romance'],
#  ['Drama', 'Romance', 'War'],
#  ['Crime', 'Film-Noir', 'Mystery'],
#  ['Drama', 'Family', 'Musical'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Drama', 'History', 'Romance'],
#  ['Comedy'],
#  ['Drama', 'Film-Noir'],
#  ['Drama', 'Mystery'],
#  ['Adventure', 'Sci-Fi'],
#  ['Adventure', 'Romance', 'War'],
#  ['Drama'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Mystery', 'Romance'],
#  ['Action', 'Romance', 'Thriller'],
#  ['Drama', 'Film-Noir', 'Romance'],
#  ['Film-Noir', 'Mystery', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Crime', 'Mystery', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Musical', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Comedy', 'Musical', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Adventure', 'Romance'],
#  ['Action', 'Adventure', 'Romance'],
#  ['Crime', 'Drama', 'Film-Noir'],
#  ['Comedy', 'Drama', 'Fantasy'],
#  ['Adventure', 'Drama', 'Fantasy'],
#  ['Comedy', 'Musical', 'Romance'],
#  ['Comedy', 'War'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Western'],
#  ['Drama'],
#  ['Comedy', 'Crime', 'Mystery'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Drama', 'Family', 'Fantasy'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Family', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Drama'],
#  ['Comedy', 'Music', 'Mystery'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Fantasy', 'Romance'],
#  ['Drama', 'Family'],
#  ['Crime', 'Drama', 'Film-Noir'],
#  ['Comedy', 'Musical', 'Romance'],
#  ['Romance', 'Western'],
#  ['Mystery', 'Thriller'],
#  ['Drama', 'War'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Horror'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Mystery', 'Romance'],
#  ['Comedy', 'Musical'],
#  ['Drama', 'Romance', 'War'],
#  ['Crime', 'Music', 'Mystery'],
#  ['Drama'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Action', 'Crime', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Documentary', 'Biography', 'Music'],
#  ['Adventure', 'Drama', 'Family'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Drama', 'Music', 'Romance'],
#  ['Action', 'Crime', 'Mystery'],
#  ['Biography', 'Drama', 'Thriller'],
#  ['Thriller'],
#  ['Biography', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Action', 'Crime', 'Drama'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy', 'Crime', 'Thriller'],
#  ['Comedy', 'Crime', 'Thriller'],
#  ['Comedy'],
#  ['Romance', 'Comedy'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Crime', 'Drama'],
#  ['Family', 'Comedy', 'Western'],
#  ['Family', 'Western', 'Adventure'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Comedy', 'Family', 'Sport'],
#  ['Comedy', 'Family', 'Fantasy'],
#  ['Family', 'Drama', 'Adventure'],
#  ['Comedy', 'Family', 'Romance'],
#  ['Drama', 'Family'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Family', 'Comedy', 'Fantasy'],
#  ['Adventure', 'Family'],
#  ['Comedy', 'Crime', 'Family'],
#  ['Adventure', 'Drama', 'Family'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Comedy', 'Family', 'Fantasy'],
#  ['Animation', 'Family', 'Fantasy'],
#  ['Animation', 'Short', 'Comedy'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Animation', 'Drama', 'Family'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Comedy', 'Family', 'Fantasy'],
#  ['Animation', 'Drama', 'Family'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Animation', 'Adventure', 'Family'],
#  ['Animation', 'Adventure', 'Drama'],
#  ...]

# %%
#take only first genre
#takes a long time relatve to other code for iterating 
for i in range(len(data)):
    try:
        data['Genre'][i] = genre[i][0]
    except:
        #if genre[i] has only one index in it we don't need to change anything
        continue 
data
# Out:
# C:\Users\amrme\AppData\Local\Temp/ipykernel_3116/1408255563.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Genre'][i] = genre[i][0]
#        imdbId                           Imdb Link  \
# 0      114709  http://www.imdb.com/title/tt114709
# 1      113497  http://www.imdb.com/title/tt113497
# 2      113228  http://www.imdb.com/title/tt113228
# 3      114885  http://www.imdb.com/title/tt114885
# 4      113041  http://www.imdb.com/title/tt113041
# ...       ...                                 ...
# 38878   83291   http://www.imdb.com/title/tt83291
# 38879   83168   http://www.imdb.com/title/tt83168
# 38880   82875   http://www.imdb.com/title/tt82875
# 38881  815258  http://www.imdb.com/title/tt815258
# 38882   79142   http://www.imdb.com/title/tt79142
#
#                              Title  IMDB Score      Genre  \
# 0                        Toy Story         8.3  Animation
# 1                          Jumanji         6.9     Action
# 2                 Grumpier Old Men         6.6     Comedy
# 3                Waiting to Exhale         5.7     Comedy
# 4      Father of the Bride Part II         5.9     Comedy
# ...                            ...         ...        ...
# 38878               Los violadores         5.5     Action
# 38879               Tanya's Island         4.3      Drama
# 38880               Pacific Banana         4.7     Comedy
# 38881  Werewolf in a Womens Prison         4.5     Horror
# 38882              Xiao zi ming da         6.5     Action
#
#                                                   Poster  Year
# 0      https://images-na.ssl-images-amazon.com/images...  1995
# 1      https://images-na.ssl-images-amazon.com/images...  1995
# 2      https://images-na.ssl-images-amazon.com/images...  1995
# 3      https://images-na.ssl-images-amazon.com/images...  1995
# 4      https://images-na.ssl-images-amazon.com/images...  1995
# ...                                                  ...   ...
# 38878  https://images-na.ssl-images-amazon.com/images...  1981
# 38879  https://images-na.ssl-images-amazon.com/images...  1980
# 38880  https://images-na.ssl-images-amazon.com/images...  1981
# 38881  https://images-na.ssl-images-amazon.com/images...  2006
# 38882  https://images-na.ssl-images-amazon.com/images...  1979
#
# [38883 rows x 7 columns]

# %%
# for i in range(len(data)):
#     for j in range(i , len(data)):
#         if i==j:
#             continue
        
#         if ((data['Title'][j].__str__) == (data['Title'][i].__str__)):
#             print(f"{i}  {j}")
#             print(f"{data['Title'][i]}   {data['Title'][j]}")

##UNNEEDED CODE
##NO MOVIES WITH SAME NAME
##THIS CODE TAKES A VERY LONG TIME ITERATING
